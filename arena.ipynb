# %%
from board import Board
from game import Game
from player.random_player import RandomPlayer
from player.human_player import HumanPlayer
from player.AI_player import AIPlayer

# %%
black_player = AIPlayer('X')
black_player.policy = 'Alpha-Beta'
white_player = AIPlayer('O')
white_player.policy = 'Alpha-Beta'

# %%
game = Game(black_player, white_player)
game.run()
# Out:
# =====开始游戏!=====
#
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . . . . .
# 4 . . . O X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 2 / 0 / 0
# 白   棋: 2 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . X . . . .
# 4 . . . X X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 4 / 0 / 0
# 白   棋: 1 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . O X . . . .
# 4 . . . O X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 3 / 0 / 0
# 白   棋: 3 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . X X X . . . .
# 4 . . . O X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 5 / 0 / 0
# 白   棋: 2 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . O . . . .
# 3 . X X O . . . .
# 4 . . . O X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 4 / 0 / 0
# 白   棋: 4 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . . . X . . . .
# 2 . . . X . . . .
# 3 . X X X . . . .
# 4 . . . X X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 8 / 0 / 0
# 白   棋: 1 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . . . X . . . .
# 2 . . . X . . . .
# 3 . X X X O . . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 7 / 0 / 0
# 白   棋: 3 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . . . X . . . .
# 2 . . . X . X . .
# 3 . X X X X . . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 9 / 0 / 0
# 白   棋: 2 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . . . X . . . .
# 2 . . . X O X . .
# 3 . X X X O . . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 8 / 0 / 0
# 白   棋: 4 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . . . X . . . .
# 2 . . . X X X . .
# 3 . X X X X X . .
# 4 . . . X X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 12 / 0 / 0
# 白   棋: 1 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . . . X O . . .
# 2 . . . X O X . .
# 3 . X X X O X . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 9 / 0 / 0
# 白   棋: 5 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . . . X X X . .
# 2 . . . X X X . .
# 3 . X X X O X . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 12 / 0 / 0
# 白   棋: 3 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . . O X X X . .
# 2 . . . O X X . .
# 3 . X X X O X . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 11 / 0 / 0
# 白   棋: 5 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . . O X X . .
# 3 . X X X O X . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 13 / 0 / 0
# 白   棋: 4 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . . O X X . .
# 3 O O O O O X . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 10 / 0 / 0
# 白   棋: 8 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . X X X X . .
# 3 O O O O O X . .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 12 / 0 / 0
# 白   棋: 7 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . X X X X . .
# 3 O O O O O O O .
# 4 . . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 11 / 0 / 0
# 白   棋: 9 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . X X X X . .
# 3 O X O O O O O .
# 4 X . . X O . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 13 / 0 / 0
# 白   棋: 8 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . X X X X . .
# 3 O X O O O O O .
# 4 O . . X O . . .
# 5 O . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 12 / 0 / 0
# 白   棋: 10 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . X X X X . .
# 3 O X X X X X X X
# 4 O . . X O . . .
# 5 O . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 18 / 0 / 0
# 白   棋: 5 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . X X X X . .
# 3 O X X X X X X X
# 4 O . . X O . . .
# 5 O . O O O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 0 / 0
# 白   棋: 7 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . . X X X X . .
# 3 O X X X X X X X
# 4 O . . X X X . .
# 5 O . O O O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 0 / 0
# 白   棋: 6 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . O X X X X . .
# 3 O X O X X X X X
# 4 O . . O X X . .
# 5 O . O O O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 0 / 0
# 白   棋: 9 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . O X X X X . .
# 3 O X O X X X X X
# 4 O . . X X X . .
# 5 O . O X X . . .
# 6 . . . X . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 0 / 0
# 白   棋: 6 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
#   A B C D E F G H
# 1 . X X X X X . .
# 2 . O X X X X . .
# 3 O X O X X X X X
# 4 O . . O X X . .
# 5 O . O X O . . .
# 6 . . . X . O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 0 / 0
# 白   棋: 9 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...

# %%
black_player.evaluate(game.board)
